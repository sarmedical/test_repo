# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_formats = ['svg']
from qiskit import *

# %%
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.15.1',
#  'qiskit-aer': '0.6.1',
#  'qiskit-ignis': '0.4.0',
#  'qiskit-ibmq-provider': '0.8.0',
#  'qiskit-aqua': '0.7.5',
#  'qiskit': '0.20.0'}

# %%
from qiskit import IBMQ

# %%
IBMQ.save_account('8f371c4cd9299d2d47d8fb8921b3ac568ddd7ee69f1677c378224aa662e56d67b1753e0117ec71562b7da34ef2f73fd82b316664e2ab8fa8dc3827a626ebfe75')
# Out:
# configrc.store_credentials:WARNING:2021-03-12 00:08:38,062: Credentials already present. Set overwrite=True to overwrite.

# %%
IBMQ.load_account()
# Out:
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider = IBMQ.get_provider('ibm-q')

# %%
Type = 0
if Type == 0:
    backend = provider.get_backend('ibmq_16_melbourne') # Quantum Computer
else: 
    backend = Aer.get_backend('qasm_simulator') # Quantum Simulator

# %% [markdown]
# The goal is to create an initial state that is dominated by $\vert 00 \rangle$ and has an equal probability of being in $\vert01\rangle$ and $\vert 11 \rangle$, while also neglecting $\vert10\rangle$

# %% [markdown]
# $ \vert \psi \rangle =  CH(1,0) R^y(2\theta,0) \vert 00 \rangle =\\$
# $   \begin{pmatrix}
#         1 & 0 & 0 & 0 \\
#         0 & \frac{1}{\sqrt{2}} & 0 & \frac{1}{\sqrt{2}} \\
#         0 & 0 & 1 & 0 \\
#         0 & \frac{1}{\sqrt{2}} & 0 & -\frac{1}{\sqrt{2}}
#     \end{pmatrix}
#     \begin{pmatrix}
#         \cos(\theta) & -\sin(\theta) & 0 & 0 \\
#         \sin(\theta) & \cos(\theta) & 0 & 0 \\
#         0 & 0 & \cos(\theta) & -\sin(\theta) \\
#         0 & 0 & \sin(\theta) & \cos(\theta)
#    \end{pmatrix}
#     \begin{pmatrix}
#         1 \\ 0 \\ 0 \\ 0
#     \end{pmatrix} =\\ \\
#     \begin{pmatrix}
#         1 & 0 & 0 & 0 \\
#         0 & \frac{1}{\sqrt{2}} & 0 & \frac{1}{\sqrt{2}} \\
#         0 & 0 & 1 & 0 \\
#         0 & \frac{1}{\sqrt{2}} & 0 & -\frac{1}{\sqrt{2}}
#     \end{pmatrix}
#     \begin{pmatrix}
#         \cos(\theta) \\ \sin(\theta) \\ 0 \\ 0
#     \end{pmatrix} = \\
#     \begin{pmatrix}
#         \cos(\theta) \\ \frac{1}{\sqrt{2}} \sin(\theta) \\ 0 \\ \frac{1}{\sqrt{2}} \sin(\theta)
#     \end{pmatrix}
# $

# %%
def init_state(circuit,theta):
    circuit.ry(theta,0)
    circuit.ch(1,0)
    return circuit

# %% [markdown]
# The init_state function takes in your circuit and a variable $\theta$ and creates our desired initial state.

# %%
def measure(circuit): 
    """This function measures the circuit at the end of a run"""
    circuit.measure(range(2),range(2))
    return circuit

def count_states(circuit,shots=1024):
    """This function is responsible for executing a run, and extracting the state counts"""
    job_sim = execute(circuit, backend, shots=shots)
    result_sim = job_sim.result()
    counts = result_sim.get_counts(circuit)
    return counts

def prob(state,count,shots):
    """This function takes the counts and returns the probability of the desired state"""
    if (state in count.keys()) == False:
        return 0
    else:
        probability = count[str(state)] / shots
        return probability

# %%
def P(theta,shots = 1024):
    """P_{i}"""
    c = QuantumCircuit(2,2) # Set up the default circuit with 2 qubits
    init_state(c,theta) # initialize the qubits
    measure(c) 
    counts = count_states(c,shots)
    return counts

def Pxx(theta,shots = 1024):
    """P_{i}^{xx}"""
    c = QuantumCircuit(2,2)
    init_state(c,theta)
    c.h(0)
    c.h(1)
    measure(c)
    counts = count_states(c,shots)
    return counts

def Pyy(theta,shots = 1024):
    """P_{i}^{yy}"""
    c = QuantumCircuit(2,2)
    init_state(c,theta)
    c.rx(np.pi/2,0)
    c.rx(np.pi/2,1)
    measure(c)
    counts = count_states(c,shots)
    return counts

def Pix(theta,shots = 1024):
    """P_{i}^{x}"""
    c = QuantumCircuit(2,2) 
    init_state(c,theta)
    c.h(0)
    measure(c)
    counts = count_states(c,shots)
    return counts

def Pzx(theta,shots = 1024):
    """P_{i}^{x}"""
    c = QuantumCircuit(2,2) 
    init_state(c,theta)
    c.h(0)
    measure(c)
    counts = count_states(c,shots)
    return counts

# %%
def Hamiltonian(theta,shots=1024,g=1):
    # experiments
    e1 =  P(theta,shots=shots)
    e2 = Pxx(theta,shots=shots)
    e3 = Pix(theta,shots=shots)
    e4 = Pzx(theta,shots=shots)
    e5 = Pyy(theta,shots=shots)
    # probabilities
    P_00 = prob('00',e1,shots=shots) 
    
    Pxx_00 = prob('00',e2,shots=shots)
    Pxx_11 = prob('11',e2,shots=shots)
    
    Pix_00 = prob('00',e3,shots=shots)
    Pix_01 = prob('01',e3,shots=shots)
    
    Pzx_00 = prob('00',e4,shots=shots)
    Pzx_11 = prob('11',e4,shots=shots)
    
    Pyy_00 = prob('00',e5,shots=shots)
    Pyy_11 = prob('11',e5,shots=shots)
    #hamiltonian
    H_E = 3*(1 - P_00)
    H_B = (1/2)*( 5*(Pxx_00 + Pxx_11) + 5*(Pix_00 + Pix_01) + 3*(Pzx_00 + Pzx_11) - 3*(Pyy_00 + Pyy_11) -5)
    H = (g**2 /2)*H_E - (1/(2*g**2))*H_B
    return H

# %%
theta_list = np.linspace(0,5,100)

# %%
g = 5
H_list = np.array([ Hamiltonian(theta,shots=10**3,g=g) for theta in theta_list]) 
# H_list_6 = np.array([ Hamiltonian(theta,shots=10**6) for theta in theta_list])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-4859b2fcf0ee> in <module>
#       1 g = 5
# ----> 2 H_list = np.array([ Hamiltonian(theta,shots=10**3,g=g) for theta in theta_list])
#       3 # H_list_6 = np.array([ Hamiltonian(theta,shots=10**6) for theta in theta_list])
#
# <ipython-input-13-4859b2fcf0ee> in <listcomp>(.0)
#       1 g = 5
# ----> 2 H_list = np.array([ Hamiltonian(theta,shots=10**3,g=g) for theta in theta_list])
#       3 # H_list_6 = np.array([ Hamiltonian(theta,shots=10**6) for theta in theta_list])
#
# <ipython-input-11-fc48f5ed4c27> in Hamiltonian(theta, shots, g)
#       2     # experiments
#       3     e1 =  P(theta,shots=shots)
# ----> 4     e2 = Pxx(theta,shots=shots)
#       5     e3 = Pix(theta,shots=shots)
#       6     e4 = Pzx(theta,shots=shots)
#
# <ipython-input-10-5439886dd390> in Pxx(theta, shots)
#      14     c.h(1)
#      15     measure(c)
# ---> 16     counts = count_states(c,shots)
#      17     return counts
#      18
#
# <ipython-input-9-c9095f79e447> in count_states(circuit, shots)
#       7     """This function is responsible for executing a run, and extracting the state counts"""
#       8     job_sim = execute(circuit, backend, shots=shots)
# ----> 9     result_sim = job_sim.result()
#      10     counts = result_sim.get_counts(circuit)
#      11     return counts
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\qiskit\providers\ibmq\job\ibmqjob.py in result(self, timeout, wait, partial, refresh)
#     274         """
#     275         # pylint: disable=arguments-differ
# --> 276         if not self._wait_for_completion(timeout=timeout, wait=wait,
#     277                                          required_status=(JobStatus.DONE,)):
#     278             if self._status is JobStatus.CANCELLED:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\qiskit\providers\ibmq\job\ibmqjob.py in _wait_for_completion(self, timeout, wait, required_status, status_queue)
#     871
#     872         try:
# --> 873             status_response = self._api_client.job_final_status(
#     874                 self.job_id(), timeout=timeout, wait=wait, status_queue=status_queue)
#     875         except UserTimeoutExceededError:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\qiskit\providers\ibmq\api\clients\account.py in job_final_status(self, job_id, timeout, wait, status_queue)
#     359             start_time = time.time()
#     360             try:
# --> 361                 status_response = self._job_final_status_websocket(
#     362                     job_id=job_id, timeout=timeout, status_queue=status_queue)
#     363             except WebsocketTimeoutError as ex:
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\qiskit\providers\ibmq\api\clients\account.py in _job_final_status_websocket(self, job_id, timeout, status_queue)
#     411             else:
#     412                 raise
# --> 413         return loop.run_until_complete(
#     414             self.client_ws.get_job_status(job_id, timeout=timeout, status_queue=status_queue))
#     415
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\nest_asyncio.py in run_until_complete(self, future)
#      87                 f._log_destroy_pending = False
#      88             while not f.done():
# ---> 89                 self._run_once()
#      90                 if self._stopping:
#      91                     break
#
# c:\users\acer\appdata\local\programs\python\python38\lib\site-packages\nest_asyncio.py in _run_once(self)
#     111             else min(max(0, scheduled[0]._when - now), 10) if scheduled \
#     112             else None
# --> 113         event_list = self._selector.select(timeout)
#     114         self._process_events(event_list)
#     115
#
# c:\users\acer\appdata\local\programs\python\python38\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# c:\users\acer\appdata\local\programs\python\python38\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:

# %%
M = (0.5*g**2)*np.array([[0,0,0,0],[0,3,0,0],[0,0,3,0],[0,0,0,3]]) - (0.5/g**2)*np.array([[0,2,0,2],[2,0,0.5,0],[0,0.5,0,0.5],[2,0,0.5,0] ])
minE = np.min( np.linalg.eig(M)[0] )

# %%
plt.figure(figsize=[8,5])
plt.plot(theta_list,H_list,'b.')
# plt.plot(theta_list,H_list_6,'g-')
plt.xlabel(r'$\theta$')
plt.ylabel(r'$ \langle \Psi \vert H \vert \Psi \rangle $')
plt.axhline(0,color='grey',lw=1)
plt.axvline(0,color='grey',lw=1)
plt.axhline( minE ,color='red',ls='--',label='g ='+str(g),lw=1)
plt.legend()
plt.show()
