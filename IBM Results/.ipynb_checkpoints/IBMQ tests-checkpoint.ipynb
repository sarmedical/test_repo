# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_formats = ['svg']
from qiskit import *

# %%
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.15.1',
#  'qiskit-aer': '0.6.1',
#  'qiskit-ignis': '0.4.0',
#  'qiskit-ibmq-provider': '0.8.0',
#  'qiskit-aqua': '0.7.5',
#  'qiskit': '0.20.0'}

# %%
# IBMQ.save_account('8f371c4cd9299d2d47d8fb8921b3ac568ddd7ee69f1677c378224aa662e56d67b1753e0117ec71562b7da34ef2f73fd82b316664e2ab8fa8dc3827a626ebfe75')

# %%
# IBMQ.load_account()

# %%
theta = 0
shots=1e3
g= 5

# %%
qr = QuantumRegister(11)
cr = ClassicalRegister(11)
circuit = QuantumCircuit(qr,cr)

circuit.ry(theta,1)
circuit.ch(1,2)

circuit.ry(theta,3)
circuit.ch(3,4)
circuit.h(3)
circuit.h(4)

circuit.ry(theta,5)
circuit.ch(5,6)
circuit.rx(np.pi/2,5)
circuit.rx(np.pi/2,6)

circuit.ry(theta,7)
circuit.ch(7,8)
circuit.h(7)

circuit.ry(theta,9)
circuit.ch(9,10)
circuit.h(9)


circuit.measure(qr,cr)

# %%
# %matplotlib inline

# %%
circuit.draw(output='mpl')

# %%
IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2021-03-20 21:15:04,803: Credentials are already in use. The existing account in the session will be replaced.
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
QC_type = 0
if QC_type == 0:
    provider = IBMQ.get_provider('ibm-q')
    backend = provider.get_backend('ibmq_16_melbourne') # Quantum Computer
else: 
    backend = Aer.get_backend('qasm_simulator') # Quantum Simulator

# %%
result = execute(circuit, backend, shots=shots).result()
count = result.get_counts(circuit)

# %%
0000000000

# %%
def prob(block,qq,count,shots):
    if block == 'e':
        [i,j] = [8,9]
    elif block == 'xx':
        [i,j] = [6,7]
    elif block == 'yy':
        [i,j] = [4,5]
    elif block == 'zx':
        [i,j] = [2,3]
    elif block == 'ix':
        [i,j] = [0,1]
    P=0
    for k in list(count.keys()): 
        pieces = []
        for n in range(len(k)):
            pieces.append(k[n])
        if str(pieces[i])+str(pieces[j]) == qq:
            P += count[k]
    return P / shots

# %%
def Hamiltonian(theta,count,shots=1024,g=1):
    P_00 = prob('e','00',count=count,shots=shots) 
    
    Pxx_00 = prob('xx','00',count=count,shots=shots)
    Pxx_11 = prob('xx','11',count=count,shots=shots)

    Pyy_00 = prob('yy','00',count=count,shots=shots)
    Pyy_11 = prob('yy','11',count=count,shots=shots)

    Pzx_00 = prob('zx','00',count=count,shots=shots)
    Pzx_11 = prob('zx','11',count=count,shots=shots)

    Pix_00 = prob('ix','00',count=count,shots=shots)
    Pix_10 = prob('ix','10',count=count,shots=shots)
    #hamiltonian
    H_E = 3*(1 - P_00)
    H_B = (1/2)*( 5*(Pxx_00 + Pxx_11) + 5*(Pix_00 + Pix_10) + 3*(Pzx_00 + Pzx_11) - 3*(Pyy_00 + Pyy_11) -5)
    H = (g**2 /2)*H_E - (1/(2*g**2))*H_B
    return H

# %%
H = Hamiltonian(theta,count=count,shots=shots,g=g)

# %%
H

# %%
f = open(g_5_results.txt,'a+')

# %%
item = [theta,H]
f.write( "%r\n" %item )
f.close()
